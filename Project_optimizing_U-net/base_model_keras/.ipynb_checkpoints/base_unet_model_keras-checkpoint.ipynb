# %%
import glob
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

IM_WIDTH = 256
IM_HEIGHT = 256

# %%
train_files = []
mask_files = glob.glob('../data/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

# %%
#Lets plot some samples
rows, cols = 3, 3

fig = plt.figure(figsize=(10, 10))

for i in range(1, rows * cols + 1):
    fig.add_subplot(rows, cols, i)
    img_path = train_files[i]
    msk_path = mask_files[i]
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    msk = cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk, alpha=0.4)
    
plt.show()

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode = "rgb",
        mask_color_mode = "grayscale",
        image_save_prefix = "image",
        mask_save_prefix = "mask",
        save_to_dir = None,
        target_size = (256, 256),
        seed = 1234):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen  = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef = K.flatten(y_true)
    y_predf = K.flatten(y_pred)
    And = K.sum(y_truef * y_predf)
    
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    
    return jac

def jac_distance(y_true, y_pred):
    y_truef = K.flatten(y_true)
    y_predf = K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1   = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1   = BatchNormalization(axis=3)(conv1)
    bn1   = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2   = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2   = BatchNormalization(axis=3)(conv2)
    bn2   = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3   = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3   = BatchNormalization(axis=3)(conv3)
    bn3   = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4   = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4   = BatchNormalization(axis=3)(conv4)
    bn4   = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5   = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5   = BatchNormalization(axis=3)(conv5)
    bn5   = Activation('relu')(bn5)

    up6   = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6   = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6   = BatchNormalization(axis=3)(conv6)
    bn6   = Activation('relu')(bn6)

    up7   = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7   = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7   = BatchNormalization(axis=3)(conv7)
    bn7   = Activation('relu')(bn7)

    up8   = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8   = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8   = BatchNormalization(axis=3)(conv8)
    bn8   = Activation('relu')(bn8)

    up9   = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9   = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9   = BatchNormalization(axis=3)(conv9)
    bn9   = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df, test_size=0.1)
df_train, df_val = train_test_split(df_train, test_size=0.2)

# %%
EPOCHS = 150
BATCH_SIZE = 64
LEARNING_RATE = 0.0005

train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

valid_generator_args = dict(rotation_range=0,
                            width_shift_range=0,
                            height_shift_range=0,
                            shear_range=0,
                            zoom_range=0,
                            horizontal_flip=False,
                            fill_mode='nearest')

train_gen = train_generator(df_train, BATCH_SIZE,
                            train_generator_args,
                            target_size=(IM_HEIGHT, IM_WIDTH))
    
valid_gen = train_generator(df_val, BATCH_SIZE,
                            valid_generator_args,
                            target_size=(IM_HEIGHT, IM_WIDTH))
    
model = unet(input_size=(IM_HEIGHT, IM_WIDTH, 3))

optimizer = Adam(lr=LEARNING_RATE)
callbacks = [
    EarlyStopping(patience=20, restore_best_weights=True), 
    ReduceLROnPlateau(patience=10)
]

model.compile(optimizer=optimizer, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(df_val) / BATCH_SIZE,
                    verbose=2)

model.save('../weights/u-net_best')
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/150
# Found 708 validated image filenames.
# Found 708 validated image filenames.
# 44/44 - 61s - loss: -1.1181e-01 - binary_accuracy: 0.9007 - iou: 0.0614 - dice_coef: 0.1142 - val_loss: -2.6126e-02 - val_binary_accuracy: 0.9877 - val_iou: 0.0137 - val_dice_coef: 0.0269
# Epoch 2/150
# 44/44 - 58s - loss: -2.1935e-01 - binary_accuracy: 0.9827 - iou: 0.1250 - dice_coef: 0.2199 - val_loss: -2.7776e-02 - val_binary_accuracy: 0.2928 - val_iou: 0.0140 - val_dice_coef: 0.0275
# Epoch 3/150
# 44/44 - 57s - loss: -3.6065e-01 - binary_accuracy: 0.9910 - iou: 0.2262 - dice_coef: 0.3648 - val_loss: -2.2111e-02 - val_binary_accuracy: 0.0447 - val_iou: 0.0110 - val_dice_coef: 0.0216
# Epoch 4/150
# 44/44 - 57s - loss: -4.8750e-01 - binary_accuracy: 0.9924 - iou: 0.3223 - dice_coef: 0.4843 - val_loss: -2.3942e-01 - val_binary_accuracy: 0.9833 - val_iou: 0.1269 - val_dice_coef: 0.2213
# Epoch 5/150
# 44/44 - 57s - loss: -5.4852e-01 - binary_accuracy: 0.9929 - iou: 0.3894 - dice_coef: 0.5530 - val_loss: -2.1896e-02 - val_binary_accuracy: 0.0651 - val_iou: 0.0122 - val_dice_coef: 0.0240
# Epoch 6/150
# 44/44 - 57s - loss: -6.3194e-01 - binary_accuracy: 0.9941 - iou: 0.4655 - dice_coef: 0.6317 - val_loss: -3.7882e-02 - val_binary_accuracy: 0.4568 - val_iou: 0.0210 - val_dice_coef: 0.0409
# Epoch 7/150
# 44/44 - 57s - loss: -6.6320e-01 - binary_accuracy: 0.9943 - iou: 0.5031 - dice_coef: 0.6652 - val_loss: -1.7395e-01 - val_binary_accuracy: 0.9064 - val_iou: 0.0996 - val_dice_coef: 0.1794
# Epoch 8/150
# 44/44 - 58s - loss: -6.8469e-01 - binary_accuracy: 0.9944 - iou: 0.5279 - dice_coef: 0.6854 - val_loss: -5.3191e-01 - val_binary_accuracy: 0.9931 - val_iou: 0.3531 - val_dice_coef: 0.5031
# Epoch 9/150
# 44/44 - 57s - loss: -7.0812e-01 - binary_accuracy: 0.9949 - iou: 0.5566 - dice_coef: 0.7105 - val_loss: -6.5248e-01 - val_binary_accuracy: 0.9927 - val_iou: 0.4535 - val_dice_coef: 0.6030
# Epoch 10/150
# 44/44 - 58s - loss: -6.9752e-01 - binary_accuracy: 0.9946 - iou: 0.5432 - dice_coef: 0.6993 - val_loss: -5.7922e-01 - val_binary_accuracy: 0.9911 - val_iou: 0.3900 - val_dice_coef: 0.5433
# Epoch 11/150
# 44/44 - 58s - loss: -7.0029e-01 - binary_accuracy: 0.9947 - iou: 0.5478 - dice_coef: 0.7018 - val_loss: -7.1019e-01 - val_binary_accuracy: 0.9945 - val_iou: 0.5295 - val_dice_coef: 0.6708
# Epoch 12/150
# 44/44 - 57s - loss: -7.4486e-01 - binary_accuracy: 0.9953 - iou: 0.5981 - dice_coef: 0.7450 - val_loss: -6.8609e-01 - val_binary_accuracy: 0.9948 - val_iou: 0.5261 - val_dice_coef: 0.6841
# Epoch 13/150
# 44/44 - 57s - loss: -7.4586e-01 - binary_accuracy: 0.9954 - iou: 0.6024 - dice_coef: 0.7477 - val_loss: -7.4003e-01 - val_binary_accuracy: 0.9953 - val_iou: 0.5598 - val_dice_coef: 0.7010
# Epoch 14/150
# 44/44 - 57s - loss: -7.6615e-01 - binary_accuracy: 0.9957 - iou: 0.6293 - dice_coef: 0.7680 - val_loss: -7.6746e-01 - val_binary_accuracy: 0.9958 - val_iou: 0.6212 - val_dice_coef: 0.7516
# Epoch 15/150
# 44/44 - 57s - loss: -7.7114e-01 - binary_accuracy: 0.9958 - iou: 0.6301 - dice_coef: 0.7699 - val_loss: -4.2964e-01 - val_binary_accuracy: 0.9919 - val_iou: 0.3118 - val_dice_coef: 0.4574
# Epoch 16/150
# 44/44 - 57s - loss: -7.4171e-01 - binary_accuracy: 0.9952 - iou: 0.5890 - dice_coef: 0.7289 - val_loss: -7.4660e-01 - val_binary_accuracy: 0.9955 - val_iou: 0.6147 - val_dice_coef: 0.7578
# Epoch 17/150
# 44/44 - 57s - loss: -7.6845e-01 - binary_accuracy: 0.9958 - iou: 0.6243 - dice_coef: 0.7649 - val_loss: -7.7793e-01 - val_binary_accuracy: 0.9960 - val_iou: 0.6278 - val_dice_coef: 0.7683
# Epoch 18/150
# 44/44 - 58s - loss: -7.7848e-01 - binary_accuracy: 0.9959 - iou: 0.6352 - dice_coef: 0.7669 - val_loss: -8.1699e-01 - val_binary_accuracy: 0.9965 - val_iou: 0.7044 - val_dice_coef: 0.8244
# Epoch 19/150
# 44/44 - 59s - loss: -7.8136e-01 - binary_accuracy: 0.9959 - iou: 0.6466 - dice_coef: 0.7823 - val_loss: -6.4204e-01 - val_binary_accuracy: 0.9947 - val_iou: 0.4614 - val_dice_coef: 0.6242
# Epoch 20/150
# 44/44 - 57s - loss: -7.9647e-01 - binary_accuracy: 0.9960 - iou: 0.6676 - dice_coef: 0.7966 - val_loss: -8.4942e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.7481 - val_dice_coef: 0.8490
# Epoch 21/150
# 44/44 - 58s - loss: -7.9147e-01 - binary_accuracy: 0.9961 - iou: 0.6619 - dice_coef: 0.7928 - val_loss: -7.7566e-01 - val_binary_accuracy: 0.9963 - val_iou: 0.6458 - val_dice_coef: 0.7823
# Epoch 22/150
# 44/44 - 58s - loss: -7.9701e-01 - binary_accuracy: 0.9961 - iou: 0.6686 - dice_coef: 0.7967 - val_loss: -7.5166e-01 - val_binary_accuracy: 0.9954 - val_iou: 0.5935 - val_dice_coef: 0.7411
# Epoch 23/150
# 44/44 - 58s - loss: -8.1009e-01 - binary_accuracy: 0.9964 - iou: 0.6868 - dice_coef: 0.8110 - val_loss: -8.4891e-01 - val_binary_accuracy: 0.9969 - val_iou: 0.7525 - val_dice_coef: 0.8567
# Epoch 24/150
# 44/44 - 57s - loss: -8.2432e-01 - binary_accuracy: 0.9966 - iou: 0.7051 - dice_coef: 0.8243 - val_loss: -7.7565e-01 - val_binary_accuracy: 0.9959 - val_iou: 0.6369 - val_dice_coef: 0.7748
# Epoch 25/150
# 44/44 - 57s - loss: -8.1479e-01 - binary_accuracy: 0.9964 - iou: 0.6952 - dice_coef: 0.8165 - val_loss: -8.3515e-01 - val_binary_accuracy: 0.9967 - val_iou: 0.7303 - val_dice_coef: 0.8428
# Epoch 26/150
# 44/44 - 57s - loss: -4.8243e-02 - binary_accuracy: 0.9758 - iou: 0.0256 - dice_coef: 0.0483 - val_loss: -6.1291e-01 - val_binary_accuracy: 0.9919 - val_iou: 0.4554 - val_dice_coef: 0.6216
# Epoch 27/150
# 44/44 - 57s - loss: -7.0825e-01 - binary_accuracy: 0.9889 - iou: 0.5742 - dice_coef: 0.7081 - val_loss: -6.7586e-01 - val_binary_accuracy: 0.9923 - val_iou: 0.5229 - val_dice_coef: 0.6844
# Epoch 28/150
# 44/44 - 57s - loss: -7.9405e-01 - binary_accuracy: 0.9961 - iou: 0.6647 - dice_coef: 0.7940 - val_loss: -8.1162e-01 - val_binary_accuracy: 0.9964 - val_iou: 0.6840 - val_dice_coef: 0.8102
# Epoch 29/150
# 44/44 - 57s - loss: -8.2401e-01 - binary_accuracy: 0.9967 - iou: 0.7071 - dice_coef: 0.8242 - val_loss: -8.4898e-01 - val_binary_accuracy: 0.9971 - val_iou: 0.7236 - val_dice_coef: 0.8367
# Epoch 30/150
# 44/44 - 58s - loss: -6.7622e-02 - binary_accuracy: 0.9739 - iou: 0.0362 - dice_coef: 0.0664 - val_loss: -4.4206e-01 - val_binary_accuracy: 0.9733 - val_iou: 0.2853 - val_dice_coef: 0.4413
# Epoch 31/150
# 44/44 - 57s - loss: -6.0792e-01 - binary_accuracy: 0.9857 - iou: 0.4687 - dice_coef: 0.6106 - val_loss: -8.0917e-01 - val_binary_accuracy: 0.9961 - val_iou: 0.6925 - val_dice_coef: 0.8159
# Epoch 32/150
# 44/44 - 57s - loss: -8.1761e-01 - binary_accuracy: 0.9965 - iou: 0.6994 - dice_coef: 0.8182 - val_loss: -8.6523e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7747 - val_dice_coef: 0.8684
# Epoch 33/150
# 44/44 - 58s - loss: -8.3761e-01 - binary_accuracy: 0.9969 - iou: 0.7225 - dice_coef: 0.8354 - val_loss: -8.5022e-01 - val_binary_accuracy: 0.9970 - val_iou: 0.7385 - val_dice_coef: 0.8488
# Epoch 34/150
# 44/44 - 57s - loss: -8.4997e-01 - binary_accuracy: 0.9971 - iou: 0.7422 - dice_coef: 0.8506 - val_loss: -8.7109e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7733 - val_dice_coef: 0.8716
# Epoch 35/150
# 44/44 - 57s - loss: -8.4468e-01 - binary_accuracy: 0.9970 - iou: 0.7351 - dice_coef: 0.8434 - val_loss: -8.6578e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7741 - val_dice_coef: 0.8718
# Epoch 36/150
# 44/44 - 59s - loss: -8.4899e-01 - binary_accuracy: 0.9970 - iou: 0.7443 - dice_coef: 0.8501 - val_loss: -8.7093e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7814 - val_dice_coef: 0.8762
# Epoch 37/150
# 44/44 - 58s - loss: -8.4796e-01 - binary_accuracy: 0.9972 - iou: 0.7417 - dice_coef: 0.8472 - val_loss: -8.6244e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7682 - val_dice_coef: 0.8627
# Epoch 38/150
# 44/44 - 58s - loss: -8.5522e-01 - binary_accuracy: 0.9972 - iou: 0.7518 - dice_coef: 0.8563 - val_loss: -8.6370e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7228 - val_dice_coef: 0.8148
# Epoch 39/150
# 44/44 - 58s - loss: -8.4726e-01 - binary_accuracy: 0.9971 - iou: 0.7433 - dice_coef: 0.8469 - val_loss: -8.6945e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7647 - val_dice_coef: 0.8656
# Epoch 40/150
# 44/44 - 57s - loss: -8.5255e-01 - binary_accuracy: 0.9971 - iou: 0.7442 - dice_coef: 0.8479 - val_loss: -8.6514e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7644 - val_dice_coef: 0.8658
# Epoch 41/150
# 44/44 - 57s - loss: -8.5852e-01 - binary_accuracy: 0.9973 - iou: 0.7559 - dice_coef: 0.8592 - val_loss: -8.7473e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7811 - val_dice_coef: 0.8765
# Epoch 42/150
# 44/44 - 58s - loss: -8.5366e-01 - binary_accuracy: 0.9972 - iou: 0.7517 - dice_coef: 0.8529 - val_loss: -8.7284e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7499 - val_dice_coef: 0.8505
# Epoch 43/150
# 44/44 - 57s - loss: -8.5199e-01 - binary_accuracy: 0.9972 - iou: 0.7383 - dice_coef: 0.8429 - val_loss: -8.8306e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7986 - val_dice_coef: 0.8827
# Epoch 44/150
# 44/44 - 58s - loss: -8.5638e-01 - binary_accuracy: 0.9973 - iou: 0.7490 - dice_coef: 0.8528 - val_loss: -8.6424e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7751 - val_dice_coef: 0.8714
# Epoch 45/150
# 44/44 - 58s - loss: -8.5361e-01 - binary_accuracy: 0.9972 - iou: 0.7510 - dice_coef: 0.8531 - val_loss: -8.6991e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7393 - val_dice_coef: 0.8405
# Epoch 46/150
# 44/44 - 58s - loss: -8.5750e-01 - binary_accuracy: 0.9973 - iou: 0.7586 - dice_coef: 0.8579 - val_loss: -8.7089e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7771 - val_dice_coef: 0.8732
# Epoch 47/150
# 44/44 - 58s - loss: -8.5845e-01 - binary_accuracy: 0.9972 - iou: 0.7595 - dice_coef: 0.8597 - val_loss: -8.7859e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7891 - val_dice_coef: 0.8815
# Epoch 48/150
# 44/44 - 58s - loss: -8.5445e-01 - binary_accuracy: 0.9971 - iou: 0.7555 - dice_coef: 0.8559 - val_loss: -8.7861e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7902 - val_dice_coef: 0.8820
# Epoch 49/150
# 44/44 - 58s - loss: -8.5592e-01 - binary_accuracy: 0.9972 - iou: 0.7435 - dice_coef: 0.8407 - val_loss: -8.7309e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7832 - val_dice_coef: 0.8770
# Epoch 50/150
# 44/44 - 57s - loss: -8.5665e-01 - binary_accuracy: 0.9972 - iou: 0.7552 - dice_coef: 0.8558 - val_loss: -8.7037e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7782 - val_dice_coef: 0.8745
# Epoch 51/150
# 44/44 - 58s - loss: -8.5975e-01 - binary_accuracy: 0.9973 - iou: 0.7598 - dice_coef: 0.8602 - val_loss: -8.8439e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8005 - val_dice_coef: 0.8885
# Epoch 52/150
# 44/44 - 58s - loss: -8.6108e-01 - binary_accuracy: 0.9972 - iou: 0.7613 - dice_coef: 0.8611 - val_loss: -8.7817e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7941 - val_dice_coef: 0.8838
# Epoch 53/150
# 44/44 - 58s - loss: -8.5960e-01 - binary_accuracy: 0.9973 - iou: 0.7579 - dice_coef: 0.8558 - val_loss: -8.8072e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7969 - val_dice_coef: 0.8819
# Epoch 54/150
# 44/44 - 58s - loss: -8.6173e-01 - binary_accuracy: 0.9973 - iou: 0.7606 - dice_coef: 0.8603 - val_loss: -8.8489e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7865 - val_dice_coef: 0.8787
# Epoch 55/150
# 44/44 - 57s - loss: -8.5822e-01 - binary_accuracy: 0.9972 - iou: 0.7574 - dice_coef: 0.8591 - val_loss: -8.6866e-01 - val_binary_accuracy: 0.9973 - val_iou: 0.7474 - val_dice_coef: 0.8505
# Epoch 56/150
# 44/44 - 57s - loss: -8.6109e-01 - binary_accuracy: 0.9972 - iou: 0.7595 - dice_coef: 0.8598 - val_loss: -8.7894e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7890 - val_dice_coef: 0.8813
# Epoch 57/150
# 44/44 - 57s - loss: -8.5728e-01 - binary_accuracy: 0.9974 - iou: 0.7619 - dice_coef: 0.8586 - val_loss: -8.8750e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.8015 - val_dice_coef: 0.8892
# Epoch 58/150
# 44/44 - 58s - loss: -8.5999e-01 - binary_accuracy: 0.9971 - iou: 0.7608 - dice_coef: 0.8598 - val_loss: -8.7479e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7824 - val_dice_coef: 0.8770
# Epoch 59/150
# 44/44 - 58s - loss: -8.6405e-01 - binary_accuracy: 0.9974 - iou: 0.7646 - dice_coef: 0.8645 - val_loss: -8.8503e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.8038 - val_dice_coef: 0.8903
# Epoch 60/150
# 44/44 - 58s - loss: -8.6197e-01 - binary_accuracy: 0.9974 - iou: 0.7665 - dice_coef: 0.8626 - val_loss: -8.8401e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7927 - val_dice_coef: 0.8839
# Epoch 61/150
# 44/44 - 58s - loss: -8.6587e-01 - binary_accuracy: 0.9974 - iou: 0.7682 - dice_coef: 0.8656 - val_loss: -8.8181e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7917 - val_dice_coef: 0.8830
# Epoch 62/150
# 44/44 - 57s - loss: -8.6001e-01 - binary_accuracy: 0.9974 - iou: 0.7575 - dice_coef: 0.8547 - val_loss: -8.8973e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8111 - val_dice_coef: 0.8915
# Epoch 63/150
# 44/44 - 58s - loss: -8.6396e-01 - binary_accuracy: 0.9975 - iou: 0.7658 - dice_coef: 0.8620 - val_loss: -8.8062e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7978 - val_dice_coef: 0.8867
# Epoch 64/150
# 44/44 - 58s - loss: -8.5976e-01 - binary_accuracy: 0.9973 - iou: 0.7521 - dice_coef: 0.8472 - val_loss: -8.7992e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7898 - val_dice_coef: 0.8813
# Epoch 65/150
# 44/44 - 59s - loss: -8.6656e-01 - binary_accuracy: 0.9974 - iou: 0.7710 - dice_coef: 0.8670 - val_loss: -8.8431e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7985 - val_dice_coef: 0.8873
# Epoch 66/150
# 44/44 - 58s - loss: -8.6422e-01 - binary_accuracy: 0.9975 - iou: 0.7665 - dice_coef: 0.8621 - val_loss: -8.7519e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7727 - val_dice_coef: 0.8701
# Epoch 67/150
# 44/44 - 57s - loss: -8.6386e-01 - binary_accuracy: 0.9974 - iou: 0.7631 - dice_coef: 0.8587 - val_loss: -8.7799e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7914 - val_dice_coef: 0.8825
# Epoch 68/150
# 44/44 - 57s - loss: -8.6400e-01 - binary_accuracy: 0.9975 - iou: 0.7710 - dice_coef: 0.8636 - val_loss: -8.9329e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7994 - val_dice_coef: 0.8877
# Epoch 69/150
# 44/44 - 57s - loss: -8.6932e-01 - binary_accuracy: 0.9975 - iou: 0.7753 - dice_coef: 0.8700 - val_loss: -8.8260e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7917 - val_dice_coef: 0.8830
# Epoch 70/150
# 44/44 - 58s - loss: -8.7067e-01 - binary_accuracy: 0.9974 - iou: 0.7770 - dice_coef: 0.8712 - val_loss: -8.8340e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8030 - val_dice_coef: 0.8865
# Epoch 71/150
# 44/44 - 59s - loss: -8.6918e-01 - binary_accuracy: 0.9975 - iou: 0.7666 - dice_coef: 0.8626 - val_loss: -8.8231e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7887 - val_dice_coef: 0.8805
# Epoch 72/150
# 44/44 - 57s - loss: -8.6315e-01 - binary_accuracy: 0.9974 - iou: 0.7677 - dice_coef: 0.8640 - val_loss: -8.8243e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.8007 - val_dice_coef: 0.8850
# Epoch 73/150
# 44/44 - 58s - loss: -8.6697e-01 - binary_accuracy: 0.9974 - iou: 0.7720 - dice_coef: 0.8678 - val_loss: -8.8461e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7998 - val_dice_coef: 0.8876
# Epoch 74/150
# 44/44 - 58s - loss: -8.6778e-01 - binary_accuracy: 0.9974 - iou: 0.7770 - dice_coef: 0.8692 - val_loss: -8.8752e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.8045 - val_dice_coef: 0.8909
# Epoch 75/150
# 44/44 - 58s - loss: -8.6864e-01 - binary_accuracy: 0.9974 - iou: 0.7753 - dice_coef: 0.8695 - val_loss: -8.8733e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7981 - val_dice_coef: 0.8869
# Epoch 76/150
# 44/44 - 58s - loss: -8.7167e-01 - binary_accuracy: 0.9976 - iou: 0.7801 - dice_coef: 0.8725 - val_loss: -8.7290e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7346 - val_dice_coef: 0.8217
# Epoch 77/150
# 44/44 - 57s - loss: -8.6763e-01 - binary_accuracy: 0.9975 - iou: 0.7759 - dice_coef: 0.8680 - val_loss: -8.8747e-01 - val_binary_accuracy: 0.9974 - val_iou: 0.7956 - val_dice_coef: 0.8856
# Epoch 78/150
# 44/44 - 57s - loss: -8.6763e-01 - binary_accuracy: 0.9974 - iou: 0.7732 - dice_coef: 0.8677 - val_loss: -8.7806e-01 - val_binary_accuracy: 0.9975 - val_iou: 0.7953 - val_dice_coef: 0.8847
# Epoch 79/150
# 44/44 - 57s - loss: -8.6856e-01 - binary_accuracy: 0.9975 - iou: 0.7772 - dice_coef: 0.8699 - val_loss: -8.7804e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.7562 - val_dice_coef: 0.8550
# Epoch 80/150
# 44/44 - 57s - loss: -8.6716e-01 - binary_accuracy: 0.9974 - iou: 0.7774 - dice_coef: 0.8684 - val_loss: -8.9091e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8108 - val_dice_coef: 0.8944
# Epoch 81/150
# 44/44 - 57s - loss: -8.7253e-01 - binary_accuracy: 0.9975 - iou: 0.7807 - dice_coef: 0.8733 - val_loss: -8.8564e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7953 - val_dice_coef: 0.8851
# Epoch 82/150
# 44/44 - 58s - loss: -8.6716e-01 - binary_accuracy: 0.9975 - iou: 0.7746 - dice_coef: 0.8674 - val_loss: -8.9015e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.8042 - val_dice_coef: 0.8907
# Epoch 83/150
# 44/44 - 58s - loss: -8.6895e-01 - binary_accuracy: 0.9974 - iou: 0.7764 - dice_coef: 0.8689 - val_loss: -8.8461e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.8045 - val_dice_coef: 0.8906
# Epoch 84/150
# 44/44 - 58s - loss: -8.7184e-01 - binary_accuracy: 0.9974 - iou: 0.7809 - dice_coef: 0.8722 - val_loss: -8.8249e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7837 - val_dice_coef: 0.8749
# Epoch 85/150
# 44/44 - 58s - loss: -8.6900e-01 - binary_accuracy: 0.9976 - iou: 0.7791 - dice_coef: 0.8702 - val_loss: -8.8563e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7432 - val_dice_coef: 0.8261
# Epoch 86/150
# 44/44 - 57s - loss: -8.6994e-01 - binary_accuracy: 0.9975 - iou: 0.7768 - dice_coef: 0.8699 - val_loss: -8.8905e-01 - val_binary_accuracy: 0.9978 - val_iou: 0.8067 - val_dice_coef: 0.8924
# Epoch 87/150
# 44/44 - 58s - loss: -8.7449e-01 - binary_accuracy: 0.9976 - iou: 0.7840 - dice_coef: 0.8758 - val_loss: -8.8653e-01 - val_binary_accuracy: 0.9976 - val_iou: 0.7906 - val_dice_coef: 0.8822
# Epoch 88/150
# 44/44 - 59s - loss: -8.7113e-01 - binary_accuracy: 0.9975 - iou: 0.7809 - dice_coef: 0.8722 - val_loss: -8.9070e-01 - val_binary_accuracy: 0.9977 - val_iou: 0.7914 - val_dice_coef: 0.8822
# INFO:tensorflow:Assets written to: weights/u-net_best.pt/assets

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                           valid_generator_args,
                           target_size=(IM_HEIGHT, IM_WIDTH))

results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)

print("Test lost: ", results[0])
print("Test IOU: ", results[1])
print("Test Dice Coefficent: ", results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 6/6 [==============================] - 3s 542ms/step - loss: -0.8663 - binary_accuracy: 0.9974 - iou: 0.7535 - dice_coef: 0.8581
# Test lost:  -0.8663213849067688
# Test IOU:  0.9973729848861694
# Test Dice Coefficent:  0.7535263299942017

# %%
for i in range(30):
    
    index = np.random.randint(1, len(df_test.index))
    img   = cv2.imread(df_test['filename'].iloc[index])
    img   = cv2.resize(img ,(IM_HEIGHT, IM_WIDTH))
    img   = img / 255
    img   = img[np.newaxis, :, :, :]
    pred  = model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
